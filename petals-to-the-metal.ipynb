# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import math, re, os

print(tf.__version__)
# Out:
# 2022-06-09 05:36:27.991607: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2022-06-09 05:36:27.991731: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2.4.1

# %% [markdown]
# Reference for importing data: https://www.kaggle.com/code/ryanholbrook/create-your-first-submission/notebook

# %%
# Detect TPU, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver() 
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() 

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# 2022-06-09 05:36:33.581909: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-09 05:36:33.584724: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2022-06-09 05:36:33.584762: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-09 05:36:33.584788: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c0e0dab346ca): /proc/driver/nvidia/version does not exist
# 2022-06-09 05:36:33.587810: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-09 05:36:33.589411: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-09 05:36:33.595091: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-09 05:36:33.626969: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-06-09 05:36:33.627030: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30043}
# 2022-06-09 05:36:33.645477: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-06-09 05:36:33.645536: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30043}
# 2022-06-09 05:36:33.646936: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30043
# REPLICAS:  8

# %%
from kaggle_datasets import KaggleDatasets

GCS_DS_PATH = KaggleDatasets().get_gcs_path('tpu-getting-started')
print(GCS_DS_PATH) # what do gcs paths look like?
# Out:
# gs://kds-02d8028567fea25689490b7b16d8093b0a671809699cf11da3dda3fc

# %%
IMAGE_SIZE = [192, 192]
GCS_PATH = GCS_DS_PATH + '/tfrecords-jpeg-192x192'
AUTO = tf.data.experimental.AUTOTUNE

TRAINING_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/train/*.tfrec')
VALIDATION_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/val/*.tfrec')
TEST_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/test/*.tfrec')
# Out:
# 2022-06-09 05:36:39.854029: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2022-06-09 05:36:39.939204: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2022-06-09 05:36:40.013390: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.

# %%
CLASSES = ['pink primrose',    'hard-leaved pocket orchid', 'canterbury bells', 'sweet pea',     'wild geranium',     'tiger lily',           'moon orchid',              'bird of paradise', 'monkshood',        'globe thistle',         # 00 - 09
           'snapdragon',       "colt's foot",               'king protea',      'spear thistle', 'yellow iris',       'globe-flower',         'purple coneflower',        'peruvian lily',    'balloon flower',   'giant white arum lily', # 10 - 19
           'fire lily',        'pincushion flower',         'fritillary',       'red ginger',    'grape hyacinth',    'corn poppy',           'prince of wales feathers', 'stemless gentian', 'artichoke',        'sweet william',         # 20 - 29
           'carnation',        'garden phlox',              'love in the mist', 'cosmos',        'alpine sea holly',  'ruby-lipped cattleya', 'cape flower',              'great masterwort', 'siam tulip',       'lenten rose',           # 30 - 39
           'barberton daisy',  'daffodil',                  'sword lily',       'poinsettia',    'bolero deep blue',  'wallflower',           'marigold',                 'buttercup',        'daisy',            'common dandelion',      # 40 - 49
           'petunia',          'wild pansy',                'primula',          'sunflower',     'lilac hibiscus',    'bishop of llandaff',   'gaura',                    'geranium',         'orange dahlia',    'pink-yellow dahlia',    # 50 - 59
           'cautleya spicata', 'japanese anemone',          'black-eyed susan', 'silverbush',    'californian poppy', 'osteospermum',         'spring crocus',            'iris',             'windflower',       'tree poppy',            # 60 - 69
           'gazania',          'azalea',                    'water lily',       'rose',          'thorn apple',       'morning glory',        'passion flower',           'lotus',            'toad lily',        'anthurium',             # 70 - 79
           'frangipani',       'clematis',                  'hibiscus',         'columbine',     'desert-rose',       'tree mallow',          'magnolia',                 'cyclamen ',        'watercress',       'canna lily',            # 80 - 89
           'hippeastrum ',     'bee balm',                  'pink quill',       'foxglove',      'bougainvillea',     'camellia',             'mallow',                   'mexican petunia',  'bromelia',         'blanket flower',        # 90 - 99
           'trumpet creeper',  'blackberry lily',           'common tulip',     'wild rose']                                                                                                                                               # 100 - 102

# %%
def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels=3)
    image = tf.cast(image, tf.float32) / 255.0  # convert image to floats in [0, 1] range
    image = tf.reshape(image, [*IMAGE_SIZE, 3]) # explicit size needed for TPU
    return image

def read_labeled_tfrecord(example):
    LABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "class": tf.io.FixedLenFeature([], tf.int64),  # shape [] means single element
    }
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    label = tf.cast(example['class'], tf.int32)
    return image, label # returns a dataset of (image, label) pairs

def read_unlabeled_tfrecord(example):
    UNLABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "id": tf.io.FixedLenFeature([], tf.string),  # shape [] means single element
        # class is missing, this competitions's challenge is to predict flower classes for the test dataset
    }
    example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    idnum = example['id']
    return image, idnum # returns a dataset of image(s)

def load_dataset(filenames, labeled=True, ordered=False):
    # Read from TFRecords. For optimal performance, reading from multiple files at once and
    # disregarding data order. Order does not matter since we will be shuffling the data anyway.

    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord if labeled else read_unlabeled_tfrecord, num_parallel_calls=AUTO)
    # returns a dataset of (image, label) pairs if labeled=True or (image, id) pairs if labeled=False
    return dataset

# %%
def data_augment(image, label):
    # Thanks to the dataset.prefetch(AUTO)
    # statement in the next function (below), this happens essentially
    # for free on TPU. Data pipeline code is executed on the "CPU"
    # part of the TPU while the TPU itself is computing gradients.
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_saturation(image, 0, 2)
    return image, label   

def get_training_dataset():
    dataset = load_dataset(TRAINING_FILENAMES, labeled=True)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_training_dataset_preview(ordered=False):
    dataset = load_dataset(TRAINING_FILENAMES, labeled=True, ordered=ordered)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(ordered=False):
    dataset = load_dataset(VALIDATION_FILENAMES, labeled=True, ordered=ordered)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO)
    return dataset

def get_test_dataset(ordered=False):
    dataset = load_dataset(TEST_FILENAMES, labeled=False, ordered=ordered)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO)
    return dataset

def count_data_items(filenames):
    # the number of data items is written in the name of the .tfrec
    # files, i.e. flowers00-230.tfrec = 230 data items
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)
NUM_VALIDATION_IMAGES = count_data_items(VALIDATION_FILENAMES)
NUM_TEST_IMAGES = count_data_items(TEST_FILENAMES)
print('Dataset: {} training images, {} validation images, {} unlabeled test images'.format(NUM_TRAINING_IMAGES, NUM_VALIDATION_IMAGES, NUM_TEST_IMAGES))
# Out:
# Dataset: 12753 training images, 3712 validation images, 7382 unlabeled test images

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
print('Batch Size: ', BATCH_SIZE)

ds_train = get_training_dataset()
ds_valid = get_validation_dataset()
ds_test = get_test_dataset()

print("Training:", ds_train)
print ("Validation:", ds_valid)
print("Test:", ds_test)
# Out:
# Batch Size:  128
# Training: <PrefetchDataset shapes: ((None, 192, 192, 3), (None,)), types: (tf.float32, tf.int32)>
# Validation: <PrefetchDataset shapes: ((None, 192, 192, 3), (None,)), types: (tf.float32, tf.int32)>
# Test: <PrefetchDataset shapes: ((None, 192, 192, 3), (None,)), types: (tf.float32, tf.string)>

# %%
np.set_printoptions(threshold=15, linewidth=80)

print("Training data shapes:")
for image, label in ds_train.take(3):
    print(image.numpy().shape, label.numpy().shape)
print("Training data label examples:", label.numpy())
# Out:
# Training data shapes:
# (128, 192, 192, 3) (128,)
# (128, 192, 192, 3) (128,)
# (128, 192, 192, 3) (128,)
# Training data label examples: [69 88 78 ... 74 70  4]
# 2022-06-09 05:36:42.960587: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 61, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1654753002.956298813","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 61, Output num: 0","grpc_status":3}

# %%
sample_batch_size = 16

def create_batch(ds):
    ds_iter = iter(ds.unbatch().batch(sample_batch_size))
    return next(ds_iter)    

def batch_to_images(ds_batch):
    images, labels = ds_batch
    return images.numpy(), labels.numpy()

def show_batch(ds):
    sample_batch = create_batch(ds)
    images, labels = batch_to_images(sample_batch)
    ncols = math.floor((math.sqrt(len(labels))))
    nrows = len(labels) // ncols
    
    fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 9))
    for ax, image, label in zip(axs.flatten(), images, labels):
        ax.imshow(image)
        ax.set_title(CLASSES[label])
        ax.axis('off')

# %%
show_batch(ds_train)

# %%
def ds_to_labels(ds, num_images):
    return next(iter(ds.unbatch().map(lambda image, label: label).batch(num_images))).numpy()

def plot_class_dist(ds, num_images):
    labels = ds_to_labels(ds, num_images)
    names = map(lambda x: CLASSES[x], labels)
    names_df = pd.DataFrame(names)
    names_df.value_counts().plot.barh(figsize=(15,20))

# %%
plot_class_dist(ds_train, NUM_TRAINING_IMAGES)

# %%
plot_class_dist(ds_valid, NUM_VALIDATION_IMAGES)

# %%
class FlowerClassifier(tf.keras.Model):
    def __init__(self, input_shape, n_classes):
        super().__init__(self)
        self.input_layer = tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=input_shape)
        self.conv1 = tf.keras.layers.Conv2D(32, (3,3), activation='relu')
        self.max_pool = tf.keras.layers.MaxPooling2D(2,2)
        self.dropout = tf.keras.layers.Dropout(0.25)
        self.flatten = tf.keras.layers.Flatten()
        self.dense1 = tf.keras.layers.Dense(256, activation='relu')
        self.dense2 = tf.keras.layers.Dense(128, activation='relu')
        self.output_layer = tf.keras.layers.Dense(n_classes, activation='softmax')
        
    def call(self, input):
        x = self.input_layer(input)
        x = self.max_pool(x)
        x = self.dropout(x)
        x = self.conv1(x)
        x = self.max_pool(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.dense1(x)
        x = self.dropout(x)
        x = self.dense2(x)
        x = self.dropout(x)
        x = self.output_layer(x)
        return x

# %%
for image, label in ds_train.take(1):
    image = image.numpy()
    BATCH_SIZE = image.shape[0]
    DIM_X = image.shape[1]
    DIM_Y = image.shape[2]
    DIM_CH = image.shape[3]

INPUT_SHAPE = [DIM_X, DIM_Y, DIM_CH]

ds_train = get_training_dataset_preview()
labels = ds_to_labels(ds_train, NUM_TRAINING_IMAGES)

N_CLASSES = len(set(labels))

STEPS_PER_EPOCH = NUM_TRAINING_IMAGES // BATCH_SIZE

print('INPUT_SHAPE: {}, N_CLASSES: {}, STEPS_PER_EPOCH: {}'.format(INPUT_SHAPE, N_CLASSES, STEPS_PER_EPOCH))
# Out:
# 2022-06-09 05:56:22.890103: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 43099, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1654754182.890025862","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 43099, Output num: 0","grpc_status":3}
# INPUT_SHAPE: [192, 192, 3], N_CLASSES: 104, STEPS_PER_EPOCH: 99

# %%
tf.keras.backend.clear_session()

with strategy.scope():
    model = FlowerClassifier(INPUT_SHAPE, N_CLASSES)

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
EPOCHS = 35
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-4 * 10**(epoch/35))

history = model.fit(
    x = get_training_dataset(),
    validation_data = get_validation_dataset(),
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs = EPOCHS,
    callbacks=[lr_schedule]
)
# Out:
# Epoch 1/35
# 99/99 [==============================] - 18s 103ms/step - loss: 4.5142 - accuracy: 0.0465 - val_loss: 4.2992 - val_accuracy: 0.1094
# Epoch 2/35
# 99/99 [==============================] - 6s 56ms/step - loss: 4.2097 - accuracy: 0.0804 - val_loss: 4.0931 - val_accuracy: 0.1226
# Epoch 3/35
# 99/99 [==============================] - 6s 56ms/step - loss: 4.0201 - accuracy: 0.1036 - val_loss: 3.9318 - val_accuracy: 0.1390
# Epoch 4/35
# 99/99 [==============================] - 6s 56ms/step - loss: 3.8711 - accuracy: 0.1200 - val_loss: 3.8363 - val_accuracy: 0.1579
# Epoch 5/35
# 99/99 [==============================] - 6s 56ms/step - loss: 3.7585 - accuracy: 0.1339 - val_loss: 3.6324 - val_accuracy: 0.1759
# Epoch 6/35
# 99/99 [==============================] - 6s 56ms/step - loss: 3.6642 - accuracy: 0.1422 - val_loss: 3.5684 - val_accuracy: 0.1934
# Epoch 7/35
# 99/99 [==============================] - 6s 56ms/step - loss: 3.6029 - accuracy: 0.1499 - val_loss: 3.5209 - val_accuracy: 0.2031
# Epoch 8/35
# 99/99 [==============================] - 6s 56ms/step - loss: 3.5023 - accuracy: 0.1644 - val_loss: 3.4277 - val_accuracy: 0.2155
# Epoch 9/35
# 99/99 [==============================] - 6s 59ms/step - loss: 3.4557 - accuracy: 0.1716 - val_loss: 3.2895 - val_accuracy: 0.2314
# Epoch 10/35
# 99/99 [==============================] - 5s 56ms/step - loss: 3.3888 - accuracy: 0.1774 - val_loss: 3.2524 - val_accuracy: 0.2365
# Epoch 11/35
# 99/99 [==============================] - 5s 55ms/step - loss: 3.3381 - accuracy: 0.1847 - val_loss: 3.1536 - val_accuracy: 0.2352
# Epoch 12/35
# 99/99 [==============================] - 6s 56ms/step - loss: 3.2971 - accuracy: 0.1985 - val_loss: 3.0810 - val_accuracy: 0.2441
# Epoch 13/35
# 99/99 [==============================] - 5s 55ms/step - loss: 3.1927 - accuracy: 0.2116 - val_loss: 3.0806 - val_accuracy: 0.2565
# Epoch 14/35
# 99/99 [==============================] - 5s 55ms/step - loss: 3.1408 - accuracy: 0.2156 - val_loss: 3.0224 - val_accuracy: 0.2705
# Epoch 15/35
# 99/99 [==============================] - 5s 55ms/step - loss: 3.1118 - accuracy: 0.2264 - val_loss: 2.9387 - val_accuracy: 0.2831
# Epoch 16/35
# 99/99 [==============================] - 5s 55ms/step - loss: 3.0420 - accuracy: 0.2328 - val_loss: 2.8625 - val_accuracy: 0.2883
# Epoch 17/35
# 99/99 [==============================] - 6s 56ms/step - loss: 2.9475 - accuracy: 0.2517 - val_loss: 2.8590 - val_accuracy: 0.3039
# Epoch 18/35
# 99/99 [==============================] - 6s 59ms/step - loss: 2.8787 - accuracy: 0.2677 - val_loss: 2.7613 - val_accuracy: 0.3103
# Epoch 19/35
# 99/99 [==============================] - 5s 55ms/step - loss: 2.8008 - accuracy: 0.2836 - val_loss: 2.8077 - val_accuracy: 0.3233
# Epoch 20/35
# 99/99 [==============================] - 5s 55ms/step - loss: 2.7580 - accuracy: 0.2869 - val_loss: 2.6929 - val_accuracy: 0.3305
# Epoch 21/35
# 99/99 [==============================] - 5s 55ms/step - loss: 2.7145 - accuracy: 0.2983 - val_loss: 2.6390 - val_accuracy: 0.3244
# Epoch 22/35
# 99/99 [==============================] - 5s 55ms/step - loss: 2.6012 - accuracy: 0.3202 - val_loss: 2.6323 - val_accuracy: 0.3324
# Epoch 23/35
# 99/99 [==============================] - 6s 56ms/step - loss: 2.5362 - accuracy: 0.3362 - val_loss: 2.6585 - val_accuracy: 0.3335
# Epoch 24/35
# 99/99 [==============================] - 6s 56ms/step - loss: 2.4624 - accuracy: 0.3516 - val_loss: 2.5494 - val_accuracy: 0.3459
# Epoch 25/35
# 99/99 [==============================] - 6s 56ms/step - loss: 2.3824 - accuracy: 0.3758 - val_loss: 2.5816 - val_accuracy: 0.3389
# Epoch 26/35
# 99/99 [==============================] - 6s 56ms/step - loss: 2.3112 - accuracy: 0.3830 - val_loss: 2.6037 - val_accuracy: 0.3451
# Epoch 27/35
# 99/99 [==============================] - 5s 55ms/step - loss: 2.1724 - accuracy: 0.4266 - val_loss: 2.5655 - val_accuracy: 0.3505
# Epoch 28/35
# 99/99 [==============================] - 6s 61ms/step - loss: 2.1416 - accuracy: 0.4271 - val_loss: 2.5651 - val_accuracy: 0.3502
# Epoch 29/35
# 99/99 [==============================] - 6s 56ms/step - loss: 2.0644 - accuracy: 0.4504 - val_loss: 2.5529 - val_accuracy: 0.3543
# Epoch 30/35
# 99/99 [==============================] - 6s 57ms/step - loss: 1.9630 - accuracy: 0.4630 - val_loss: 2.6282 - val_accuracy: 0.3473
# Epoch 31/35
# 99/99 [==============================] - 6s 56ms/step - loss: 1.8956 - accuracy: 0.4923 - val_loss: 2.6642 - val_accuracy: 0.3295
# Epoch 32/35
# 99/99 [==============================] - 5s 55ms/step - loss: 1.7704 - accuracy: 0.5189 - val_loss: 2.6101 - val_accuracy: 0.3429
# Epoch 33/35
# 99/99 [==============================] - 5s 55ms/step - loss: 1.7268 - accuracy: 0.5304 - val_loss: 2.6536 - val_accuracy: 0.3411
# Epoch 34/35
# 99/99 [==============================] - 5s 55ms/step - loss: 1.6338 - accuracy: 0.5541 - val_loss: 2.7538 - val_accuracy: 0.3101
# Epoch 35/35
# 99/99 [==============================] - 6s 56ms/step - loss: 1.6185 - accuracy: 0.5550 - val_loss: 2.7246 - val_accuracy: 0.3327

# %%
loss = history.history['loss']
acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']

epochs = range(len(loss))
plt.subplots(figsize=(14,7))
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.title('Accuracy')
plt.legend(loc=0)
plt.show()

# %%
plt.subplots(figsize=(14,7))
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.plot(epochs, loss, 'r', label='Training loss')
plt.title('Loss')
plt.legend(loc=0)
plt.show()

# %%
ds_train = get_training_dataset_preview(ordered=True)
ds_valid = get_validation_dataset(ordered=True)

x_train = ds_train.map(lambda image, label: image)
x_valid = ds_valid.map(lambda image, label: image)

train_preds = model.predict(x_train)
train_preds = np.argmax(train_preds, axis=-1)

valid_preds = model.predict(x_valid)
valid_preds = np.argmax(valid_preds, axis=-1)

y_train = ds_to_labels(ds_train, NUM_TRAINING_IMAGES)
y_valid = ds_to_labels(ds_valid, NUM_VALIDATION_IMAGES)
# Out:
# 2022-06-09 05:58:43.651780: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 43532, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1654754323.651607856","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 43532, Output num: 0","grpc_status":3}

# %%
from sklearn.metrics import classification_report

print('VALIDATION SET REPORT:\n', classification_report(y_valid, valid_preds, target_names=CLASSES))
print('TRAINING SET REPORT:\n', classification_report(y_train, train_preds, target_names=CLASSES))
# Out:
# VALIDATION SET REPORT:
#                             precision    recall  f1-score   support
#
#             pink primrose       0.37      0.32      0.34        79
# hard-leaved pocket orchid       1.00      0.43      0.60         7
#          canterbury bells       0.00      0.00      0.00         6
#                 sweet pea       0.00      0.00      0.00         6
#             wild geranium       0.42      0.52      0.46       205
#                tiger lily       0.17      0.32      0.22        25
#               moon orchid       0.00      0.00      0.00         5
#          bird of paradise       0.46      0.39      0.42        31
#                 monkshood       0.25      0.12      0.16        25
#             globe thistle       0.41      0.71      0.52        24
#                snapdragon       0.00      0.00      0.00        40
#               colt's foot       0.33      0.08      0.12        13
#               king protea       0.61      0.41      0.49        27
#             spear thistle       0.35      0.49      0.41        77
#               yellow iris       0.36      0.44      0.39        66
#              globe-flower       0.00      0.00      0.00         6
#         purple coneflower       0.43      0.56      0.49        16
#             peruvian lily       0.20      0.14      0.17        14
#            balloon flower       0.15      0.35      0.21        26
#     giant white arum lily       0.00      0.00      0.00         8
#                 fire lily       1.00      0.17      0.29         6
#         pincushion flower       0.16      0.25      0.19        28
#                fritillary       0.60      0.21      0.32        14
#                red ginger       0.22      0.33      0.27         6
#            grape hyacinth       0.25      0.38      0.30        24
#                corn poppy       0.50      0.12      0.20        24
#  prince of wales feathers       0.00      0.00      0.00         6
#          stemless gentian       0.50      0.50      0.50        10
#                 artichoke       0.28      0.26      0.27        34
#             sweet william       0.15      0.12      0.14        32
#                 carnation       0.15      0.19      0.17        31
#              garden phlox       0.00      0.00      0.00         7
#          love in the mist       0.50      0.14      0.22         7
#                    cosmos       0.00      0.00      0.00         6
#          alpine sea holly       0.00      0.00      0.00         5
#      ruby-lipped cattleya       0.50      0.18      0.27        11
#               cape flower       0.47      0.53      0.50        17
#          great masterwort       0.50      0.12      0.20         8
#                siam tulip       0.00      0.00      0.00         5
#               lenten rose       0.33      0.33      0.33        21
#           barberton daisy       0.25      0.22      0.24        18
#                  daffodil       0.02      0.04      0.03        28
#                sword lily       0.33      0.06      0.10        18
#                poinsettia       0.18      0.41      0.25        32
#          bolero deep blue       0.00      0.00      0.00         5
#                wallflower       0.25      0.44      0.32        50
#                  marigold       0.27      0.08      0.12        37
#                 buttercup       0.37      0.25      0.30        76
#                     daisy       0.32      0.52      0.40       123
#          common dandelion       0.46      0.55      0.50       164
#                   petunia       0.26      0.17      0.21        58
#                wild pansy       0.80      0.13      0.23        30
#                   primula       0.00      0.00      0.00        33
#                 sunflower       0.49      0.61      0.54       134
#            lilac hibiscus       0.14      0.09      0.11        11
#        bishop of llandaff       0.88      0.41      0.56        17
#                     gaura       0.36      0.38      0.37        26
#                  geranium       0.55      0.61      0.58        18
#             orange dahlia       0.43      0.60      0.50        10
#        pink-yellow dahlia       0.60      0.53      0.56        17
#          cautleya spicata       0.33      0.38      0.35         8
#          japanese anemone       0.50      0.12      0.20         8
#          black-eyed susan       0.47      0.33      0.39        27
#                silverbush       0.00      0.00      0.00         8
#         californian poppy       0.67      0.25      0.36        16
#              osteospermum       0.00      0.00      0.00         9
#             spring crocus       1.00      0.17      0.29         6
#                      iris       0.43      0.62      0.51       228
#                windflower       0.28      0.25      0.26        76
#                tree poppy       0.25      0.22      0.24        27
#                   gazania       0.32      0.50      0.39        30
#                    azalea       0.18      0.12      0.15        40
#                water lily       0.33      0.20      0.25        49
#                      rose       0.24      0.41      0.30       134
#               thorn apple       0.18      0.25      0.21        36
#             morning glory       0.48      0.22      0.31        89
#            passion flower       0.49      0.63      0.55        35
#                     lotus       0.47      0.34      0.39        41
#                 toad lily       0.24      0.36      0.29        25
#                 anthurium       0.23      0.09      0.13        34
#                frangipani       0.17      0.13      0.15        45
#                  clematis       0.08      0.03      0.05        29
#                  hibiscus       0.11      0.05      0.07        39
#                 columbine       0.13      0.09      0.11        33
#               desert-rose       0.00      0.00      0.00         9
#               tree mallow       0.80      0.44      0.57         9
#                  magnolia       0.00      0.00      0.00        35
#                 cyclamen        0.31      0.12      0.17        43
#                watercress       0.63      0.43      0.51        28
#                canna lily       0.00      0.00      0.00        13
#              hippeastrum        0.24      0.23      0.23        31
#                  bee balm       0.20      0.25      0.22        32
#                pink quill       0.00      0.00      0.00         7
#                  foxglove       0.38      0.29      0.33        41
#             bougainvillea       0.13      0.18      0.16        38
#                  camellia       0.18      0.16      0.17        37
#                    mallow       0.05      0.03      0.04        29
#           mexican petunia       0.13      0.17      0.15        12
#                  bromelia       0.40      0.20      0.27        10
#            blanket flower       0.18      0.29      0.22         7
#           trumpet creeper       0.00      0.00      0.00         9
#           blackberry lily       0.00      0.00      0.00         7
#              common tulip       0.35      0.26      0.30       114
#                 wild rose       0.40      0.37      0.38       216
#
#                  accuracy                           0.33      3712
#                 macro avg       0.29      0.23      0.24      3712
#              weighted avg       0.33      0.33      0.31      3712
#
# TRAINING SET REPORT:
#                             precision    recall  f1-score   support
#
#             pink primrose       0.91      0.92      0.92       272
# hard-leaved pocket orchid       0.89      0.96      0.93        26
#          canterbury bells       1.00      0.05      0.10        20
#                 sweet pea       0.00      0.00      0.00        21
#             wild geranium       0.88      0.92      0.90       703
#                tiger lily       0.62      0.83      0.71        87
#               moon orchid       1.00      0.72      0.84        18
#          bird of paradise       0.98      0.95      0.97       105
#                 monkshood       0.90      0.80      0.85        87
#             globe thistle       0.85      0.98      0.91        84
#                snapdragon       0.83      0.73      0.78       136
#               colt's foot       1.00      0.72      0.84        43
#               king protea       0.95      0.86      0.90        92
#             spear thistle       0.90      0.97      0.93       263
#               yellow iris       0.82      0.98      0.89       227
#              globe-flower       1.00      0.29      0.44        21
#         purple coneflower       0.95      1.00      0.97        55
#             peruvian lily       0.78      0.56      0.65        50
#            balloon flower       0.51      0.84      0.64        90
#     giant white arum lily       1.00      0.31      0.47        26
#                 fire lily       1.00      0.89      0.94        19
#         pincushion flower       0.73      0.77      0.75        96
#                fritillary       0.97      0.79      0.87        48
#                red ginger       0.73      0.84      0.78        19
#            grape hyacinth       0.74      0.94      0.83        85
#                corn poppy       0.85      0.49      0.63        83
#  prince of wales feathers       0.93      0.62      0.74        21
#          stemless gentian       0.91      0.94      0.93        34
#                 artichoke       0.90      0.87      0.89       119
#             sweet william       0.74      0.78      0.76       109
#                 carnation       0.53      0.57      0.55       105
#              garden phlox       1.00      0.04      0.08        24
#          love in the mist       0.95      0.83      0.88        23
#                    cosmos       1.00      0.25      0.40        20
#          alpine sea holly       0.93      0.72      0.81        18
#      ruby-lipped cattleya       0.97      0.92      0.94        36
#               cape flower       0.83      0.95      0.89        57
#          great masterwort       0.83      0.73      0.78        26
#                siam tulip       1.00      0.63      0.77        19
#               lenten rose       0.82      0.93      0.87        73
#           barberton daisy       0.72      0.81      0.76        64
#                  daffodil       0.71      0.90      0.79        96
#                sword lily       0.93      0.60      0.73        63
#                poinsettia       0.52      0.85      0.64       110
#          bolero deep blue       0.75      0.17      0.27        18
#                wallflower       0.66      0.83      0.74       172
#                  marigold       0.88      0.46      0.61       125
#                 buttercup       0.90      0.75      0.82       261
#                     daisy       0.80      0.93      0.86       422
#          common dandelion       0.84      0.92      0.88       563
#                   petunia       0.85      0.67      0.75       201
#                wild pansy       0.98      0.78      0.87       105
#                   primula       0.83      0.38      0.52       115
#                 sunflower       0.85      0.97      0.90       460
#            lilac hibiscus       0.87      0.70      0.78        37
#        bishop of llandaff       0.97      0.67      0.80        58
#                     gaura       0.97      0.93      0.95        89
#                  geranium       0.68      0.89      0.77        63
#             orange dahlia       0.94      0.94      0.94        36
#        pink-yellow dahlia       0.92      1.00      0.96        58
#          cautleya spicata       0.96      0.96      0.96        27
#          japanese anemone       0.89      0.59      0.71        29
#          black-eyed susan       0.95      0.86      0.90        93
#                silverbush       0.89      0.89      0.89        28
#         californian poppy       0.95      0.65      0.77        55
#              osteospermum       0.96      0.79      0.87        33
#             spring crocus       1.00      0.24      0.38        21
#                      iris       0.87      0.95      0.91       782
#                windflower       0.92      0.93      0.93       260
#                tree poppy       0.83      0.93      0.87        94
#                   gazania       0.73      0.94      0.82       104
#                    azalea       0.78      0.55      0.65       137
#                water lily       0.95      0.86      0.90       167
#                      rose       0.65      0.85      0.74       460
#               thorn apple       0.71      0.92      0.80       125
#             morning glory       0.97      0.85      0.90       306
#            passion flower       0.86      0.97      0.91       119
#                     lotus       0.94      0.85      0.89       139
#                 toad lily       0.78      0.91      0.84        86
#                 anthurium       0.87      0.61      0.72       118
#                frangipani       0.83      0.88      0.86       153
#                  clematis       0.86      0.66      0.75       101
#                  hibiscus       0.78      0.54      0.64       134
#                 columbine       0.81      0.64      0.72       112
#               desert-rose       1.00      0.10      0.18        31
#               tree mallow       0.83      0.66      0.73        29
#                  magnolia       0.92      0.79      0.85       120
#                 cyclamen        0.91      0.73      0.81       146
#                watercress       0.94      0.82      0.88        96
#                canna lily       0.84      0.57      0.68        46
#              hippeastrum        0.80      0.77      0.78       106
#                  bee balm       0.75      0.85      0.79       111
#                pink quill       0.85      0.92      0.88        24
#                  foxglove       0.83      0.91      0.87       139
#             bougainvillea       0.49      0.62      0.54       131
#                  camellia       0.78      0.72      0.75       127
#                    mallow       0.71      0.50      0.59       100
#           mexican petunia       0.63      0.76      0.69        41
#                  bromelia       0.79      0.91      0.85        34
#            blanket flower       1.00      0.88      0.93        24
#           trumpet creeper       0.76      0.52      0.62        31
#           blackberry lily       0.94      0.68      0.79        25
#              common tulip       0.88      0.82      0.85       390
#                 wild rose       0.91      0.90      0.91       743
#
#                  accuracy                           0.83     12753
#                 macro avg       0.85      0.74      0.76     12753
#              weighted avg       0.84      0.83      0.82     12753
